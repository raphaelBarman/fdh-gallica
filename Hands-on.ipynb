# %%
from fdh_gallica import Periodical
from fdh_gallica.parallel_process import iiif_urls_for_documents

from tqdm.autonotebook import tqdm
import pandas as pd
# Out:
# /home/raph/.conda/envs/fdh/lib/python3.7/site-packages/tqdm/autonotebook.py:17: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
# Find the iiif urls for all issues published in february between 1928 and 1932 (inclusive)
guignol = Periodical('12148/cb32785285g')

# %%
issues = []
for year in tqdm(range(1928, 1933)):
    issues.extend(guignol.issues_per_year(year))

# %%
def parse_date(document):
    return pd.to_datetime(document.oai()['results']['notice']['record']['metadata']['oai_dc:dc']['dc:date'])

# %%
selected_issues = []
for issue in tqdm(issues):
    if parse_date(issue).month == 2:
        selected_issues.append(issue)

# %%
urls, failures = iiif_urls_for_documents(selected_issues)

# %%
for _, iiif_urls in urls:
    for iiif_url in iiif_urls:
        print(iiif_url)
# Out:
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k959891g/f1/full/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k959891g/f2/full/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k959891g/f3/full/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k959891g/f4/full/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k959891g/f5/full/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k959891g/f6/full/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k959891g/f7/full/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k959891g/f8/full/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k959891g/f9/full/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k959891g/f10/full/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k959891g/f11/full/full/0/native.jpg
# https://gallica.bnf.fr/iiif/ark:/12148/bpt6k959891g/f12/full/full/0/native.jpg
# ...
